# %%
df_cleaned['is_FK_Advantage_product_numeric'] = df_cleaned['is_FK_Advantage_product'].astype(int)

X_multi = df_cleaned[['retail_price', 'is_FK_Advantage_product_numeric']]
y_multi = df_cleaned['discounted_price']


from sklearn.model_selection import train_test_split
X_train_multi, X_test_multi, y_train_multi, y_test_multi = train_test_split(X_multi, y_multi, test_size=0.2, random_state=42)

print(f"Multivariate Training set shape: X_train_multi:{X_train_multi.shape}, y_train_multi:{y_train_multi.shape}")
print(f"Multivariate Testing set shape: X_test_multi:{X_test_multi.shape}, y_test_multi:{y_test_multi.shape}")
# Out:
# Multivariate Training set shape: X_train_multi:(14966, 2), y_train_multi:(14966,)
# Multivariate Testing set shape: X_test_multi:(3742, 2), y_test_multi:(3742,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

model_multi = LinearRegression()

model_multi.fit(X_train_multi, y_train_multi)
y_pred_multi = model_multi.predict(X_test_multi)

mae_multi = mean_absolute_error(y_test_multi, y_pred_multi)
mse_multi = mean_squared_error(y_test_multi, y_pred_multi)
r2_multi = r2_score(y_test_multi, y_pred_multi)

print("Multivariate Model Coefficients:")
for feature, coef in zip(X_multi.columns, model_multi.coef_):
    print(f"  {feature}: {coef:.2f}")
print(f"Multivariate Model Intercept: {model_multi.intercept_:.2f}")
print(f"Multivariate Mean Absolute Error (MAE): {mae_multi:.2f}")
print(f"Multivariate Mean Squared Error (MSE): {mse_multi:.2f}")
print(f"Multivariate R-squared (R2): {r2_multi:.2f}")
# Out:
# Multivariate Model Coefficients:
#   retail_price: 0.75
#   is_FK_Advantage_product_numeric: 216.71
# Multivariate Model Intercept: -279.90
# Multivariate Mean Absolute Error (MAE): 488.48
# Multivariate Mean Squared Error (MSE): 6176062.82
# Multivariate R-squared (R2): 0.95
